# %% [markdown]
# <a href="https://colab.research.google.com/github/nanakoKuze/Deep-Learning/blob/main/p3_2025_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HW3: Classification
# In this exercise, you will fine-tune a pre-trained convolutional neural network (CNN) for image classification. The dataset contains chess positions labeled as either 'insufficient material' or 'sufficient material.'
# Make sure to upload the provided dataset to Google Colab before running the code.

# %% [markdown]
# ## Package Imports

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms
from torch.utils.data import DataLoader, Dataset
import os
from PIL import Image
# !unzip /chess_dataset.zip
torch.manual_seed(0)
# Out:
# Archive:  /chess_dataset.zip
#    creating: chess_dataset/
#   inflating: __MACOSX/._chess_dataset
#   inflating: chess_dataset/.DS_Store
#   inflating: __MACOSX/chess_dataset/._.DS_Store
#    creating: chess_dataset/train/
#   inflating: __MACOSX/chess_dataset/._train
#    creating: chess_dataset/val/
#   inflating: __MACOSX/chess_dataset/._val
#    creating: chess_dataset/train/sufficient_material/
#   inflating: __MACOSX/chess_dataset/train/._sufficient_material
#    creating: chess_dataset/train/insufficient_material/
#   inflating: __MACOSX/chess_dataset/train/._insufficient_material
#    creating: chess_dataset/val/sufficient_material/
#   inflating: __MACOSX/chess_dataset/val/._sufficient_material
#    creating: chess_dataset/val/insufficient_material/
#   inflating: __MACOSX/chess_dataset/val/._insufficient_material
#   inflating: chess_dataset/train/sufficient_material/sufficient-122.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-122.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-136.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-136.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-308.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-308.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-320.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-320.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-334.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-334.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-268.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-268.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-78.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-78.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-254.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-254.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-50.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-50.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-44.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-44.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-240.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-240.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-93.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-93.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-297.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-297.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-283.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-283.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-87.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-87.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-86.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-86.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-282.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-282.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-296.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-296.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-92.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-92.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-241.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-241.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-45.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-45.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-51.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-51.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-255.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-255.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-79.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-79.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-269.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-269.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-335.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-335.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-321.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-321.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-309.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-309.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-137.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-137.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-123.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-123.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-109.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-109.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-135.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-135.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-121.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-121.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-337.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-337.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-323.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-323.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-47.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-47.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-243.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-243.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-257.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-257.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-53.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-53.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-280.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-280.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-84.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-84.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-90.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-90.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-294.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-294.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-295.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-295.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-91.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-91.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-85.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-85.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-281.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-281.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-52.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-52.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-256.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-256.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-242.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-242.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-46.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-46.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-322.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-322.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-336.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-336.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-120.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-120.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-134.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-134.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-108.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-108.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-130.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-130.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-124.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-124.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-118.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-118.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-332.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-332.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-326.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-326.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-42.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-42.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-246.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-246.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-252.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-252.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-56.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-56.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-285.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-285.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-81.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-81.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-95.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-95.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-291.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-291.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-290.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-290.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-94.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-94.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-80.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-80.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-284.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-284.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-57.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-57.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-253.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-253.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-247.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-247.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-43.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-43.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-327.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-327.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-333.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-333.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-119.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-119.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-125.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-125.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-131.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-131.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-127.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-127.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-133.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-133.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-325.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-325.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-331.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-331.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-319.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-319.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-251.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-251.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-55.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-55.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-41.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-41.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-245.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-245.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-69.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-69.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-279.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-279.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-96.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-96.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-292.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-292.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-286.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-286.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-82.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-82.png
#   inflating: chess_dataset/train/sufficient_material/sufficient
png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-371.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-198.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-198.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-1.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-1.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-167.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-167.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-173.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-173.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-165.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-165.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-171.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-171.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-159.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-159.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-3.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-3.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-367.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-367.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-373.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-373.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-213.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-213.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-17.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-17.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-207.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-207.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-206.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-206.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-16.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-16.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-212.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-212.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-372.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-372.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-366.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-366.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-2.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-2.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-158.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-158.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-170.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-170.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-164.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-164.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-103.png
#   inflating: __MACOSX/chess_dataset/train/sufficient_material/._sufficient-103.png
#   inflating: chess_dataset/train/sufficient_material/sufficient-117.png
# ...
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-154.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-154.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-140.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-140.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-156.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-156.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-142.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-142.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-26.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-26.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-32.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-32.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-33.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-33.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-27.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-27.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-143.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-143.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-157.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-157.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-180.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-180.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-16.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-16.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-172.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-172.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-166.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-166.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-167.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-167.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-173.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-173.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-17.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-17.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-15.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-15.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-159.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-159.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-29.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-29.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-165.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-165.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-171.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-171.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-170.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-170.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-28.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-28.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-164.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-164.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-14.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-14.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-158.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-158.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-160.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-160.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-38.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-38.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-174.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-174.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-10.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-10.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-148.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-148.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-149.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-149.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-11.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-11.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-39.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-39.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-175.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-175.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-161.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-161.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-177.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-177.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-163.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-163.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-13.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-13.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-12.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-12.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-162.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-162.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-176.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-176.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-61.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-61.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-75.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-75.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-139.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-139.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-111.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-111.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-49.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-49.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-105.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-105.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-3.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-3.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-2.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-2.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-48.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-48.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-104.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-104.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-110.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-110.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-74.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-74.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-138.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-138.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-60.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-60.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-89.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-89.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-76.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-76.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-62.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-62.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-106.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-106.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-112.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-112.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-1.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-1.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-113.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-113.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-107.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-107.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-63.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-63.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-77.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-77.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-88.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-88.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-98.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-98.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-103.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-103.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-117.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-117.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-73.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-73.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-67.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-67.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-5.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-5.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-4.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-4.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-66.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-66.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-72.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-72.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-116.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-116.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-102.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-102.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-99.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-99.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-58.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-58.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-114.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-114.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-100.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-100.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-64.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-64.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-128.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-128.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-70.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-70.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-6.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-6.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-7.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-7.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-71.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-71.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-65.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-65.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-129.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-129.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-101.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-101.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-59.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-59.png
#   inflating: chess_dataset/val/insufficient_material/val-insufficient-115.png
#   inflating: __MACOSX/chess_dataset/val/insufficient_material/._val-insufficient-115.png

# %% [markdown]
# ## Dataset

# %%
# Define chess dataset
class ChessDataset(Dataset):
    def __init__(self, directory, transform=None):
        self.directory = directory
        self.transform = transform
        self.images = []
        self.labels = []

        for label, subdir in enumerate(['insufficient_material', 'sufficient_material']):
            subdir_path = os.path.join(directory, subdir)
            for filename in os.listdir(subdir_path):
                if filename.endswith('.png'):
                    self.images.append(os.path.join(subdir_path, filename))
                    self.labels.append(label)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image_path = self.images[idx]
        image = Image.open(image_path).convert('RGB')
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)

        return image, label

data_transforms = {
    'train': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# %% [markdown]
# ## Part (a): Model and Training Setup

# %%
# load a pretrained ResNet model
model = models.resnet18(weights='ResNet18_Weights.DEFAULT')

# create the dataset
# Make sure the 'chess_dataset' folder is correctly uploaded to Google Colab and update the path if needed
train_dataset = ChessDataset('chess_dataset/train', transform=data_transforms['train']) # put the path to your chess_dataset folder!
val_dataset = ChessDataset('chess_dataset/val', transform=data_transforms['val'])

# define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

##########################
#  Beginning of Part a  ##
##########################

# TODO: modify the fully connected layer for binary classification
# hint: it might be helpful to print(model) to see how the model is structured

# use a GPU if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model.fc = nn.Linear(model.fc.in_features, 2)
model = model.to(device)

# create the dataloader
# hint: remember to shuffle the train_loader
batch_size = 4
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ## Part (b): Train and Validation

# %%
###########################
##  Beginning of Part b  ##
###########################

def train(epoch_num):
    # set the model to train mode
    model.train()

    running_loss = 0.0
    total_loss = 0.0
    running_count = 0
    total_count = 0

    for batch_index, (inputs, labels) in enumerate(train_loader):
        inputs = inputs.to(device)
        labels = labels.to(device)

        '''
        TODO: complete the training loop. You will need to do the following:
        1. zero the parameter gradients
        2. run a forward pass
        3. run a backwards pass and optimizer step
        '''
        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        total_loss += loss.item() * inputs.size(0)
        running_count += inputs.size(0)
        total_count += inputs.size(0)

        # update loss and count
        running_loss += loss.item() * inputs.size(0)
        total_loss += loss.item() * inputs.size(0)

        running_count += inputs.size(0)
        total_count += inputs.size(0)

        # print every 50 mini-batches
        if batch_index % 50 == 49:
            print('[%d, %5d] avg batch loss: %.3f avg epoch loss: %.3f' %
                (epoch_num + 1, batch_index + 1, running_loss / running_count, total_loss / total_count))
            running_loss = 0.0
            running_count = 0


def validate():
    # set the model to evaluation mode
    model.eval()
    total_loss = 0.0
    total_correct = 0
    total_count = 0

    # Validation loop
    with torch.no_grad():  # No need to track gradients for validation
        for inputs, labels in val_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            '''
            TODO: run the forward pass (same as previous part)
            from your output (which are probabilities for each class, find the predicted class)
            '''
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            predicted = torch.max(outputs, 1)[1]

            correct_count = (predicted == labels).sum().item()

            # update loss and count
            total_loss += loss.item() * labels.size(0)
            total_correct += correct_count
            total_count += labels.size(0)

    accuracy = 100 * total_correct / total_count
    print()
    print(f"Evaluation loss: {total_loss / total_count :.3f}")
    print(f'Accuracy of the model on the validation images: {accuracy: .2f}%')
    print()

# %% [markdown]
# ## Part (c)

# %%
###########################
##  Beginning of Part c  ##
###########################

# TODO: validate your model before training
validate()

num_epochs = 1
# TODO: train and validate your model

for epoch in range(num_epochs):
    print(f"Epoch {epoch + 1}/{num_epochs}")

    # Train the model
    train(epoch)

    # Validate after each epoch
    validate()
# Out:
# Evaluation loss: 1.499
# Accuracy of the model on the validation images:  40.00%
#
# Epoch 1/1
# [1,    50] avg batch loss: 0.836 avg epoch loss: 0.836
# [1,   100] avg batch loss: 0.433 avg epoch loss: 0.635
# [1,   150] avg batch loss: 0.263 avg epoch loss: 0.511
# [1,   200] avg batch loss: 0.169 avg epoch loss: 0.425
# [1,   250] avg batch loss: 0.150 avg epoch loss: 0.370
# Evaluating model after training...
#
# Evaluation loss: 0.030
# Accuracy of the model on the validation images:  100.00%
